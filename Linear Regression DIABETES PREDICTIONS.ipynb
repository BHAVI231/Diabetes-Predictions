# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_diabetes

# %%
diabetes= load_diabetes()

# %%
diabetes.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'DESCR', 'feature_names', 'data_filename', 'target_filename'])

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
print(diabetes.frame)
# Out:
# None

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
print(diabetes.target_filename)
# Out:
# C:\Users\91888\anaconda3\lib\site-packages\sklearn\datasets\data\diabetes_target.csv.gz

# %%
print(diabetes.data)
# Out:
# [[ 0.03807591  0.05068012  0.06169621 ... -0.00259226  0.01990842
#   -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 ... -0.03949338 -0.06832974
#   -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 ... -0.00259226  0.00286377
#   -0.02593034]
#  ...
#  [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04687948
#    0.01549073]
#  [-0.04547248 -0.04464164  0.03906215 ...  0.02655962  0.04452837
#   -0.02593034]
#  [-0.04547248 -0.04464164 -0.0730303  ... -0.03949338 -0.00421986
#    0.00306441]]

# %%
print(diabetes.target)
# Out:
# [151.  75. 141. 206. 135.  97. 138.  63. 110. 310. 101.  69. 179. 185.
#  118. 171. 166. 144.  97. 168.  68.  49.  68. 245. 184. 202. 137.  85.
#  131. 283. 129.  59. 341.  87.  65. 102. 265. 276. 252.  90. 100.  55.
#   61.  92. 259.  53. 190. 142.  75. 142. 155. 225.  59. 104. 182. 128.
#   52.  37. 170. 170.  61. 144.  52. 128.  71. 163. 150.  97. 160. 178.
#   48. 270. 202. 111.  85.  42. 170. 200. 252. 113. 143.  51.  52. 210.
#   65. 141.  55. 134.  42. 111.  98. 164.  48.  96.  90. 162. 150. 279.
#   92.  83. 128. 102. 302. 198.  95.  53. 134. 144. 232.  81. 104.  59.
#  246. 297. 258. 229. 275. 281. 179. 200. 200. 173. 180.  84. 121. 161.
#   99. 109. 115. 268. 274. 158. 107.  83. 103. 272.  85. 280. 336. 281.
#  118. 317. 235.  60. 174. 259. 178. 128.  96. 126. 288.  88. 292.  71.
#  197. 186.  25.  84.  96. 195.  53. 217. 172. 131. 214.  59.  70. 220.
#  268. 152.  47.  74. 295. 101. 151. 127. 237. 225.  81. 151. 107.  64.
# ...

# %%
print(diabetes.feature_names)
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
df = pd.DataFrame(diabetes.data, columns = diabetes.feature_names)

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
#s1      tc, total serum cholesterol
 #     - s2      ldl, low-density lipoproteins
  #    - s3      hdl, high-density lipoproteins
   #   - s4      tch, total cholesterol / HDL
    #  - s5      ltg, possibly log of serum triglycerides level
     # - s6      glu, blood sugar level

df.rename(columns={"s1" : "total serum"},inplace = True)
df.rename(columns = {"s2" : "low protiens"},inplace = True)
df.rename(columns = {"s3" : "high protiens"},inplace = True)
df.rename(columns = {"s4" : "total cholestral"},inplace = True)
df.rename(columns = {"s5" : "log of serum"},inplace = True)
df.rename(columns = {"s6" : "sugar level"},inplace = True)

# %%
df.head()
# Out:
#         age       sex       bmi        bp  total serum  low protiens  \
# 0  0.038076  0.050680  0.061696  0.021872    -0.044223     -0.034821
# 1 -0.001882 -0.044642 -0.051474 -0.026328    -0.008449     -0.019163
# 2  0.085299  0.050680  0.044451 -0.005671    -0.045599     -0.034194
# 3 -0.089063 -0.044642 -0.011595 -0.036656     0.012191      0.024991
# 4  0.005383 -0.044642 -0.036385  0.021872     0.003935      0.015596
#
#    high protiens  total cholestral  log of serum  sugar level
# 0      -0.043401         -0.002592      0.019908    -0.017646
# 1       0.074412         -0.039493     -0.068330    -0.092204
# 2      -0.032356         -0.002592      0.002864    -0.025930
# 3      -0.036038          0.034309      0.022692    -0.009362
# 4       0.008142         -0.002592     -0.031991    -0.046641

# %%
df["Target"] = diabetes.target

# %%
df.head()
# Out:
#         age       sex       bmi        bp  total serum  low protiens  \
# 0  0.038076  0.050680  0.061696  0.021872    -0.044223     -0.034821
# 1 -0.001882 -0.044642 -0.051474 -0.026328    -0.008449     -0.019163
# 2  0.085299  0.050680  0.044451 -0.005671    -0.045599     -0.034194
# 3 -0.089063 -0.044642 -0.011595 -0.036656     0.012191      0.024991
# 4  0.005383 -0.044642 -0.036385  0.021872     0.003935      0.015596
#
#    high protiens  total cholestral  log of serum  sugar level  Target
# 0      -0.043401         -0.002592      0.019908    -0.017646   151.0
# 1       0.074412         -0.039493     -0.068330    -0.092204    75.0
# 2      -0.032356         -0.002592      0.002864    -0.025930   141.0
# 3      -0.036038          0.034309      0.022692    -0.009362   206.0
# 4       0.008142         -0.002592     -0.031991    -0.046641   135.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               442 non-null    float64
#  1   sex               442 non-null    float64
#  2   bmi               442 non-null    float64
#  3   bp                442 non-null    float64
#  4   total serum       442 non-null    float64
#  5   low protiens      442 non-null    float64
#  6   high protiens     442 non-null    float64
#  7   total cholestral  442 non-null    float64
#  8   log of serum      442 non-null    float64
#  9   sugar level       442 non-null    float64
#  10  Target            442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
df.describe()
# Out:
#                 age           sex           bmi            bp   total serum  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#        low protiens  high protiens  total cholestral  log of serum  \
# count  4.420000e+02   4.420000e+02      4.420000e+02  4.420000e+02
# mean   1.327024e-16  -4.574646e-16      3.777301e-16 -3.830854e-16
# std    4.761905e-02   4.761905e-02      4.761905e-02  4.761905e-02
# ...

# %%
df.corr()
# Out:
#                        age       sex       bmi        bp  total serum  \
# age               1.000000  0.173737  0.185085  0.335427     0.260061
# sex               0.173737  1.000000  0.088161  0.241013     0.035277
# bmi               0.185085  0.088161  1.000000  0.395415     0.249777
# bp                0.335427  0.241013  0.395415  1.000000     0.242470
# total serum       0.260061  0.035277  0.249777  0.242470     1.000000
# low protiens      0.219243  0.142637  0.261170  0.185558     0.896663
# high protiens    -0.075181 -0.379090 -0.366811 -0.178761     0.051519
# total cholestral  0.203841  0.332115  0.413807  0.257653     0.542207
# log of serum      0.270777  0.149918  0.446159  0.393478     0.515501
# sugar level       0.301731  0.208133  0.388680  0.390429     0.325717
# Target            0.187889  0.043062  0.586450  0.441484     0.212022
#
#                   low protiens  high protiens  total cholestral  log of serum  \
# ...

# %%
sns.pairplot(df)

# %%
sns.jointplot(x = "age", y = "Target", data = df,alpha= 0.7)

# %%
plt.scatter(df["age"],df["Target"])
plt.show()

# %%
plt.scatter(df["sex"],df["Target"])

# %%
plt.scatter(df["bmi"],df["Target"])

# %%
plt.scatter(df["bp"],df["Target"])

# %%
sns.regplot(x = "age", y = "Target", data = df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Target'>

# %%
X = df.iloc[:,:-1] # all columns except last column
y = df.iloc[:,-1] # only last column
x.head()
# Out:
#         age       sex       bmi        bp  total serum  low protiens  \
# 0  0.038076  0.050680  0.061696  0.021872    -0.044223     -0.034821
# 1 -0.001882 -0.044642 -0.051474 -0.026328    -0.008449     -0.019163
# 2  0.085299  0.050680  0.044451 -0.005671    -0.045599     -0.034194
# 3 -0.089063 -0.044642 -0.011595 -0.036656     0.012191      0.024991
# 4  0.005383 -0.044642 -0.036385  0.021872     0.003935      0.015596
#
#    high protiens  total cholestral  log of serum  sugar level
# 0      -0.043401         -0.002592      0.019908    -0.017646
# 1       0.074412         -0.039493     -0.068330    -0.092204
# 2      -0.032356         -0.002592      0.002864    -0.025930
# 3      -0.036038          0.034309      0.022692    -0.009362
# 4       0.008142         -0.002592     -0.031991    -0.046641

# %%
y.head()
# Out:
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# Name: Target, dtype: float64

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size = 0.3, random_state= 42)

# %%
X_train
# Out:
#           age       sex       bmi        bp  total serum  low protiens  \
# 225  0.030811  0.050680  0.032595  0.049415    -0.040096     -0.043589
# 412  0.074401 -0.044642  0.085408  0.063187     0.014942      0.013091
# 118 -0.056370  0.050680 -0.010517  0.025315     0.023198      0.040022
# 114  0.023546 -0.044642  0.110198  0.063187     0.013567     -0.032942
# 364  0.001751  0.050680 -0.006206 -0.019442    -0.009825      0.004949
# ..        ...       ...       ...       ...          ...           ...
# 106 -0.096328 -0.044642 -0.076264 -0.043542    -0.045599     -0.034821
# 270  0.005383  0.050680  0.030440  0.083844    -0.037344     -0.047347
# 348  0.030811 -0.044642 -0.020218 -0.005671    -0.004321     -0.029497
# 435 -0.012780 -0.044642 -0.023451 -0.040099    -0.016704      0.004636
# 102 -0.092695 -0.044642  0.028284 -0.015999     0.036958      0.024991
#
#      high protiens  total cholestral  log of serum  sugar level
# ...

# %%
print(len(X_train))
# Out:
# 309

# %%
X_test
# Out:
#           age       sex       bmi        bp  total serum  low protiens  \
# 287  0.045341 -0.044642 -0.006206 -0.015999     0.125019      0.125198
# 211  0.092564 -0.044642  0.036907  0.021872    -0.024960     -0.016658
# 72   0.063504  0.050680 -0.004050 -0.012556     0.103003      0.048790
# 321  0.096197 -0.044642  0.051996  0.079254     0.054845      0.036577
# 73   0.012648  0.050680 -0.020218 -0.002228     0.038334      0.053174
# ..        ...       ...       ...       ...          ...           ...
# 238  0.034443  0.050680 -0.009439  0.059744    -0.035968     -0.007577
# 26  -0.107226 -0.044642 -0.077342 -0.026328    -0.089630     -0.096198
# 7    0.063504  0.050680 -0.001895  0.066630     0.090620      0.108914
# 401  0.016281 -0.044642 -0.045007 -0.057314    -0.034592     -0.053923
# 108  0.019913  0.050680  0.045529  0.029906    -0.062111     -0.055802
#
#      high protiens  total cholestral  log of serum  sugar level
# ...

# %%
y_train
# Out:
# 225    208.0
# 412    261.0
# 118    179.0
# 114    258.0
# 364    262.0
#        ...
# 106    134.0
# 270    202.0
# 348    148.0
# 435     64.0
# 102    302.0
# Name: Target, Length: 309, dtype: float64

# %%
y_test
# Out:
# 287    219.0
# 211     70.0
# 72     202.0
# 321    230.0
# 73     111.0
#        ...
# 238    257.0
# 26     137.0
# 7       63.0
# 401     93.0
# 108    232.0
# Name: Target, Length: 133, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 6.42054387e-01,  1.05661647e+00,  6.19059528e-01, ...,
#          6.76301514e-01,  1.27564058e+00, -2.79646760e-04],
#        [ 1.58492079e+00, -9.46417203e-01,  1.71984406e+00, ...,
#         -8.48887236e-02,  8.95417194e-02,  1.72793733e+00],
#        [-1.24367842e+00,  1.05661647e+00, -2.79540092e-01, ...,
#          6.76301514e-01,  3.90267153e-01,  1.12306139e+00],
#        ...,
#        [ 6.42054387e-01, -9.46417203e-01, -4.81725006e-01, ...,
#         -8.46078961e-01, -2.67782097e-01, -8.66904956e-02],
#        [-3.00812016e-01, -9.46417203e-01, -5.49119978e-01, ...,
#         -8.48887236e-02, -8.43105525e-01, -8.64388135e-01],
#        [-2.02940042e+00, -9.46417203e-01,  5.29199566e-01, ...,
#         -8.46078961e-01, -1.47535315e-01, -8.66904956e-02]])

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 9.56343188e-01, -9.46417203e-01, -1.89680130e-01, ...,
#          6.76301514e-01,  6.37079627e-01, -1.73101344e-01],
#        [ 1.97778179e+00, -9.46417203e-01,  7.08919490e-01, ...,
#         -8.46078961e-01, -5.10143953e-01, -5.18744740e-01],
#        [ 1.34920419e+00,  1.05661647e+00, -1.44750149e-01, ...,
#         -8.48887236e-02,  1.72410095e+00, -4.32333891e-01],
#        ...,
#        [ 1.34920419e+00,  1.05661647e+00, -9.98201681e-02, ...,
#          3.33765907e-01, -7.87934290e-01, -2.79646760e-04],
#        [ 3.27765586e-01, -9.46417203e-01, -9.98419788e-01, ...,
#         -1.60726920e+00, -9.28982092e-01,  7.77417992e-01],
#        [ 4.06337786e-01,  1.05661647e+00,  8.88639413e-01, ...,
#          5.24063466e-01,  9.12010047e-01,  7.77417992e-01]])

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regression.coef_)
# Out:
# [  29.25034582 -261.70768053  546.29737263  388.40077257 -901.95338706
#   506.761149    121.14845948  288.02932495  659.27133846   41.37536901]

# %%
print(regression.intercept_)
# Out:
# 151.00818273080338

# %%
regression.get_params()
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'n_jobs': None,
#  'normalize': False,
#  'positive': False}

# %%
reg_pred = regression.predict(X_test)
reg_pred
# Out:
# array([-1.66049958e+02,  7.23930240e+02, -4.40458020e+02,  3.04176286e+03,
#        -4.78066104e+02, -1.13559717e+03,  2.30179149e+03,  6.47050795e+02,
#        -1.29043461e+03, -7.84364781e+02, -1.08308628e+03,  4.05861988e+02,
#        -1.85774590e+03,  1.23647872e+03, -1.01910292e+03, -3.29274163e+02,
#         1.40795929e+03,  2.20207783e+03,  1.10102225e+03,  1.51591667e+03,
#         1.17953399e+03, -1.21820699e+03, -1.58033787e+03,  8.39644479e+02,
#         1.93692625e+02,  3.33823235e+02,  9.41322098e+02,  7.87658100e+02,
#        -2.07941166e+03, -8.01244532e+02,  6.56142121e+02, -1.15396441e+03,
#        -3.97283393e+02,  7.74656833e+02,  5.35558327e+02,  8.92869692e+02,
#        -5.20396788e+02, -6.05349297e+02, -2.26879585e+01, -1.83090348e+03,
#        -1.53958634e+03, -8.16686385e+02,  4.02771529e+02,  1.32896151e+02,
#         3.93161019e+02, -1.73895543e+03, -1.52306440e+03, -7.54079553e+02,
# ...

# %%
plt.scatter(y_test,reg_pred)

# %%
residuals = y_test - reg_pred
residuals
# Out:
# 287     385.049958
# 211    -653.930240
# 72      642.458020
# 321   -2811.762857
# 73      589.066104
#           ...
# 238    -909.696022
# 26     1272.139278
# 7       570.129266
# 401    1458.612106
# 108   -1566.761839
# Name: Target, Length: 133, dtype: float64

# %%
sns.displot(residuals,bins = 16 ,kde = True)

# %%
import pylab
import scipy.stats as stats

stats.probplot(residuals, dist = "norm", plot = pylab)
pylab.show()

# %%
plt.scatter(y_test,residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

print(mean_absolute_error(y_test,reg_pred))
print(mean_squared_error(y_test,reg_pred))
print(np.sqrt(mean_squared_error(y_test,reg_pred)))
# Out:
# 916.8013203640458
# 1226080.5134352688
# 1107.2851996822087
